# %% [markdown]
# # Tokenizers testing
# - it is example of workflow with my self written tokkenizers

# %%
from src import BasicTokenizer, RegexTokenizer, GPT4Tokenizer

import numpy
import pandas

from matplotlib import pyplot as plt

import tiktoken

# %% [markdown]
# # Load the text data

# %%
file_path = "./dataset/taylorswift.txt"
file = open(file=file_path, mode="r")
text = file.read()
print(text[:100])
# Out:
# Copy paste of the Wikipedia article on Taylor Swift, as of Feb 16, 2024.
# ---
#
# Main menu
#
# WikipediaTh

# %% [markdown]
# # Regex tokenizer

# %%
tokenizer_regex = RegexTokenizer()
#
tokens = tokenizer_regex.train(text=text, vocab_size=300,verbose=True)
# Out:
# 1/44 | Merging (101, 114) to 256
# 2/44 | Merging (50, 48) to 257
# 3/44 | Merging (111, 114) to 258
# 4/44 | Merging (105, 110) to 259
# 5/44 | Merging (101, 100) to 260
# 6/44 | Merging (32, 116) to 261
# 7/44 | Merging (111, 110) to 262
# 8/44 | Merging (104, 101) to 263
# 9/44 | Merging (32, 83) to 264
# 10/44 | Merging (97, 114) to 265
# 11/44 | Merging (97, 110) to 266
# 12/44 | Merging (32, 65) to 267
# 13/44 | Merging (261, 263) to 268
# 14/44 | Merging (97, 108) to 269
# 15/44 | Merging (114, 105) to 270
# 16/44 | Merging (118, 260) to 271
# 17/44 | Merging (115, 116) to 272
# 18/44 | Merging (119, 105) to 273
# 19/44 | Merging (32, 82) to 274
# 20/44 | Merging (257, 49) to 275
# 21/44 | Merging (32, 102) to 276
# 22/44 | Merging (257, 50) to 277
# 23/44 | Merging (32, 84) to 278
# 24/44 | Merging (102, 116) to 279
# 25/44 | Merging (97, 121) to 280
# 26/44 | Merging (32, 34) to 281
# 27/44 | Merging (273, 279) to 282
# 28/44 | Merging (101, 116) to 283
# ...

# %%
print(tokenizer_regex.decode_dict)
print(tokenizer_regex.encode_dict)
# text_encoded = tokenizer.encode(text=text)
# text_reversed = tokenizer.decode(text_encoded)
#
# if text_reversed == text:
#     print("Jest git")
# Out:
# {0: b'\x00', 1: b'\x01', 2: b'\x02', 3: b'\x03', 4: b'\x04', 5: b'\x05', 6: b'\x06', 7: b'\x07', 8: b'\x08', 9: b'\t', 10: b'\n', 11: b'\x0b', 12: b'\x0c', 13: b'\r', 14: b'\x0e', 15: b'\x0f', 16: b'\x10', 17: b'\x11', 18: b'\x12', 19: b'\x13', 20: b'\x14', 21: b'\x15', 22: b'\x16', 23: b'\x17', 24: b'\x18', 25: b'\x19', 26: b'\x1a', 27